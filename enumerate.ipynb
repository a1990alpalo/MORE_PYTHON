# %%
#Using the enumerate function 

a = ["Python", "Java", "C++"]
for i, v in enumerate(a):
    print(i, v)
# Out:
# 0 Python
# 1 Java
# 2 C++

# %%
my_orders = ['Tennis','shorts','smart watch', 'T-shirt']

for order in my_orders: 
    print(order)
# Out:
# Tennis
# shorts
# smart watch
# T-shirt

# %%
a = ["A", "B", "C"]
r = list(enumerate(a))
print(r)
# Out:
# [(0, 'A'), (1, 'B'), (2, 'C')]

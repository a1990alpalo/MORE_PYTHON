# %%
products = [
    {"name": "Tennis Racket", "price": 120, "stock": 5},
    {"name": "Football", "price": 30, "stock": 12},
    {"name": "Smart Watch", "price": 250, "stock": 3},
    {"name": "Running Shoes", "price": 95, "stock": 8}
]

print("=== SPORTS STORE INVENTORY ===\n")

# enumerate gives us the index and the item
for index, product in enumerate(products, start=1):
    print(f"{index}. {product['name']}")
    print(f"   Price: ${product['price']}")
    print(f"   Stock: {product['stock']}")

    if product["stock"] < 5:
        print("   ⚠️ Low Stock!")

    print()

# Calculate inventory value
total_value = 0

for product in products:
    inventory_value = product["price"] * product["stock"]
    total_value += inventory_value

print(f"Total Inventory Value: ${total_value}")
# Out:
# === SPORTS STORE INVENTORY ===
#
# 1. Tennis Racket
#    Price: $120
#    Stock: 5
#
# 2. Football
#    Price: $30
#    Stock: 12
#
# 3. Smart Watch
#    Price: $250
#    Stock: 3
#    ⚠️ Low Stock!
#
# 4. Running Shoes
#    Price: $95
#    Stock: 8
#
# Total Inventory Value: $2470

# %%
#same code usin def functions

products = [
    {"name": "Tennis Racket", "price": 120, "stock":5},
    {"name": "Football", "price":30, "stock":12},
    {"name":"Smart Watch", "price":250, "stock":3},
    {"name":"Running Shoes", "price":95,"stock":8}
]

def display_inventory(products): 
    print("===SPORTS STORE INVENTORY ===\n")

    for index, product in enumerate(products, start=1):
        print(f"{index}.{product['name']}")
        print(f"   Price: ${product['price']}")
        print(f"   Stock:{product['stock']}")

        if product["stock"] < 5:
            print("   ⚠️Low Stock!")

        print()

def calculate_total_value(products):
    total_value = 0

    for product in products: 
        inventory_value = product["price"] * product["stock"]
        total_value += inventory_value

    return total_value

def display_total_value(products):
    total_value = calculate_total_value(products)
    print(f"Total Inventory Value: ${total_value}")


def display_low_stock(products):
    print("===LOW STOCK PRODCUTS===\n")

    for product in products: 
        if product["stock"] < 5: 
            print(f"{product['name']} only has {product['stock']} left. ")


display_low_stock(products)
display_inventory(products)         
display_total_value(products)
display_low_stock(products)
# Out:
# ===LOW STOCK PRODCUTS===
#
# Smart Watch only has 3 left.
# ===SPORTS STORE INVENTORY ===
#
# 1.Tennis Racket
#    Price: $120
#    Stock:5
#
# 2.Football
#    Price: $30
#    Stock:12
#
# 3.Smart Watch
#    Price: $250
#    Stock:3
#    ⚠️Low Stock!
#
# 4.Running Shoes
#    Price: $95
#    Stock:8
#
# Total Inventory Value: $2470
# ===LOW STOCK PRODCUTS===
#
# Smart Watch only has 3 left.
